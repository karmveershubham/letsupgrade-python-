# %%
#assignment1 
#Try 5 Different functions of the String in Python

# %%
strng="hello world"
strng.replace("world","python")

# %%
strng="this is the project of python"
strng.upper()
# Out:
# 'THIS IS THE PROJECT OF PYTHON'

# %%
strng="SHUBHAM KARMVEER"
strng.lower()
# Out:
# 'shubhamkarmveer'

# %%
s1='sk'
s2='sk'
s1.join(s2)
# Out:
# 'sskk'

# %%
name='shubham karmveer'
name.count("k")
# Out:
# 1

# %%
#assignment2
#Try 5 Differet functions of the List object in Python

# %%
lst=['shubham', 'abc',123,'letsupgrade',6,7,123,5,7,123]
lst.count(123)
# Out:
# 3

# %%
lst=['shubham', 'abc','123','letsupgrade',6,7]
lst.append([1,2,3,'abc'])
print(lst)
# Out:
# ['shubham', 'abc', '123', 'letsupgrade', 6, 7, [1, 2, 3, 'abc']]

# %%
lst.insert(4,56.7)
print(lst)
# Out:
# ['shubham', 'abc', '123', 'letsupgrade', 56.7, 56.7, '6', '7', 45]

# %%
lst1=[45,65,]
lst1.extend(lst)
print(lst1)
# Out:
# [45, 65, 'shubham', 'abc', '123', 'letsupgrade', 6, 7, [1, 2, 3, 'abc']]

# %%
lst1=['45','65',]
print(min(lst1))
# Out:
# 45

# %%
print(max(lst1))
# Out:
# 65

# %%
#assignment3
#Experiment with atleast 5 default functions of Dict

# %%
dit={'key':'value', 'key1':1, "key2":2, "key3":5.6}

# %%
dit["key2"]
# Out:
# 2

# %%
ditperson={ 'name':"shubham", 'age':18,'email':"s.karmveer1201@gmail.com"}

# %%
ditperson['age']
# Out:
# 18

# %%
ditperson['email']
# Out:
# 's.karmveer1201@gmail.com'

# %%
dit1={"subdict":{'key':'value', 'key1':1, "key2":2, "key3":5.6}}

# %%
dit1.get("subdict").get('key3')
# Out:
# 5.6

# %%
dit1.items()
# Out:
# dict_items([('subdict', {'key': 'value', 'key1': 1, 'key2': 2, 'key3': 5.6})])
