# %%
file = open('letsupgrad.txt','w')
file.write('I Love Letsupgrade,    ')
file.close()
file = open('letsupgrad.txt','r+')
print(file.read())
file.close()
file = open('letsupgrad.txt','a')
file.write('We have updted this file')
file.close()
file = open('letsupgrad.txt','r')
print(file.read())
file.close()
# Out:
# I Love Letsupgrade,
# I Love Letsupgrade,    We have updted this file

# %%
def factorial(a):
   a=int(input('factorial of [enter value]'))
   import math
   x = math.factorial(a)
   print('the factorial of' ,a,'is', x)
   
factorial(5)
# Out:
# factorial of [enter value] 5
# the factorial of 5 is 120
